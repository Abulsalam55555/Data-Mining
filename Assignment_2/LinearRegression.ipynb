# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('./movie.csv')

df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     AudienceScore  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0              70       1.747542                 64         $41.94   2008
# 1              52       1.090000                 68         $19.62   2010
# 2              35       1.211818                 43         $26.66   2010
# 3              44       0.000000                 15         $43.04   2010
# 4              72       6.267647                 28        $219.37   2008
# ..            ...            ...                ...             ...   ...
# 72             84       0.652603                 54         $29.37   2007
# 73             64       4.382857                 89         $30.68   2009
# 74             89       0.448645                 79          $8.97   2011
# 75             71       5.343622                 40        $160.31   2008
# 76             81       8.096000                 87         $60.72   2009
#
# [77 rows x 8 columns]

# %%
le = LabelEncoder()
df['Genre'] = le.fit_transform(df['Genre'])


y = pd.DataFrame(df, columns = ["Genre"])
x = pd.DataFrame(df, columns = ['AudienceScore'])

print(y)

df.describe()
# Out:
#     Genre
# 0       6
# 1       3
# 2       3
# 3       3
# 4       3
# ..    ...
# 72      9
# 73      4
# 74      4
# 75      3
# 76      8
#
# [77 rows x 1 columns]
#            Genre  AudienceScore  Profitability  Rotten Tomatoes %         Year
# count  77.000000      77.000000      77.000000          77.000000    77.000000
# mean    3.740260      63.727273       4.599483          46.701299  2009.077922
# std     1.601008      13.657113       8.031990          26.095001     1.354974
# min     0.000000      35.000000       0.000000           3.000000  2007.000000
# 25%     3.000000      52.000000       1.751351          26.000000  2008.000000
# 50%     3.000000      64.000000       2.642353          45.000000  2009.000000
# 75%     4.000000      76.000000       5.103117          64.000000  2010.000000
# max     9.000000      89.000000      66.934000          96.000000  2011.000000

# %%
plt.scatter(x, y,alpha=0.4)

plt.xlabel("Genre")
plt.ylabel("AudienceScore")

# plt.xlim(0, 9.000000)
# plt.ylim(0, 89.000000)

plt.show()

# %%
import sklearn
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x, y)
reg.coef_
reg.intercept_

plt.scatter(x, y, alpha = 0.3)

plt.xlabel("Genre")
plt.ylabel("AudienceScore")



plt.plot(x, reg.predict(x), color='black')

# plt.xlim(0, 9.000000)
# plt.ylim(0, 89.000000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-de99559fe8b1> in <module>
#       1 import sklearn
# ----> 2 from sklearn.linear_model import LinearRegression
#       3 reg = LinearRegression()
#       4 reg.fit(x, y)
#       5 reg.coef_
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\__init__.py in <module>
#       9 from ._base import LinearRegression
#      10 from ._bayes import BayesianRidge, ARDRegression
# ---> 11 from ._least_angle import (Lars, LassoLars, lars_path, lars_path_gram, LarsCV,
#      12                            LassoLarsCV, LassoLarsIC)
#      13 from ._coordinate_descent import (Lasso, ElasticNet, LassoCV, ElasticNetCV,
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_least_angle.py in <module>
#      32 @_deprecate_positional_args
#      33 def lars_path(X, y, Xy=None, *, Gram=None, max_iter=500, alpha_min=0,
# ---> 34               method='lar', copy_X=True, eps=np.finfo(np.float).eps,
#      35               copy_Gram=True, verbose=0, return_path=True,
#      36               return_n_iter=False, positive=False):
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\__init__.py in __getattr__(attr)
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder


# 'Genre' and 'AudienceScore' are columns in movie csv
df = pd.read_csv('./movie.csv')

# Convert 'Genre' column to numeric using LabelEncoder
le = LabelEncoder()
df['Genre'] = le.fit_transform(df['Genre'])

# Scatter plot with linear regression line
sns.regplot(x='Genre', y='AudienceScore', data=df, scatter_kws={'color': 'green'}, line_kws={'color': 'red'})

# Set plot title
plt.title("The Audience Score with the type of movie")

# Show the plot
plt.show()
